# %%
# Create a numpy array with 10 elements of the shape(10,1) using np.random and
#find out the mean of the elements using basic numpy functions.

import numpy as np
a=np.random.rand(10,1)
a
# Out:
# array([[0.85498401],
#        [0.10113611],
#        [0.32336994],
#        [0.49261664],
#        [0.77891081],
#        [0.59936142],
#        [0.90122525],
#        [0.64411807],
#        [0.5221404 ],
#        [0.16604735]])

# %%
mean=a.mean()
print("mean is =",mean)
# Out:
# mean is= 0.5383910005542395

# %%
#Create a numpy array with 20 elements of the shape(20,1) using np.random 
#find the variance and standard deviation of the elements.
b=np.random.rand(20,1)
variance=b.var()
sd=b.std()
print("variance is =", variance)
print("standard daviation is =", sd)
# Out:
# variance is = 0.07695754717651848
# standard daviation is = 0.2774122332856258

# %%
#Create a numpy array A of shape(10,20) and B of shape (20,25) using np.random. 
#Print the matrix which is the matrix multiplication of A and B. The shape of the new matrix should be (10,25). 
#Using basic numpy math functions only find the sum of all the elements of the new matrix.
A=np.random.rand(10,20)
B=np.random.rand(20,25)
C=np.matmul(A,B)
print(C)
# Out:
# [[6.13700223 4.57730449 6.16232182 4.88580862 6.03032156 4.45480816
#   5.25401945 6.56046263 5.59222683 6.02941362 4.96169268 5.93882349
#   4.66602068 3.52852205 6.5470204  5.47600242 4.9759921  5.36169453
#   4.41863822 3.37905293 4.93088347 5.56824499 3.97526623 5.38772437
#   6.50872795]
#  [5.90366151 4.51742551 5.03076095 5.03153836 5.95876561 3.58286422
#   5.0733242  6.05879392 5.9919736  4.98123968 4.43806991 4.71546284
#   4.12679672 3.67161328 5.95309317 5.82974335 5.17966055 5.25425179
#   4.18823315 4.09000053 4.29952439 5.40486571 3.90439749 4.76601346
#   4.74937511]
#  [6.38312993 5.23133532 6.31641539 5.31058499 5.98733099 4.89061236
#   5.86377205 7.09883576 6.32039215 6.54566057 4.44612922 5.63218568
#   5.46524599 4.22244215 6.86736326 6.37691137 5.91101825 6.07382713
#   4.34800596 3.69607152 5.27092573 5.69295408 5.07742149 5.70011181
#   6.72161207]
#  [5.89088333 4.73424057 5.61700373 3.95377715 5.91729714 3.04076616
# ...

# %%
D=np.sum(C)
print(D)
# Out:
# 1275.9839425441155

# %%
#question 4
a=np.random.rand(10,1)

# %%
def func(x):
    return 1 / (1 + np.exp(-x))

# %%
z=np.apply_along_axis(axis=0,arr=a,func1d=func)

# %%
print(z)
# Out:
# [[0.66862393]
#  [0.69711079]
#  [0.6101814 ]
#  [0.69203207]
#  [0.5234471 ]
#  [0.56751232]
#  [0.66571371]
#  [0.62864423]
#  [0.73101697]
#  [0.57984522]]
